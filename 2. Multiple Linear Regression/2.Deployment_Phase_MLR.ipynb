# %%
import pickle

# %%
loaded_model = pickle.load(open("finalized_model_Mul_linear.sav",'rb'))
results = loaded_model.predict([[100,100,100,0,0]])
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
results
# Out:
# array([[42489.07606333]])
